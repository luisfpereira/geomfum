# %%
from geomfum.dataset import NotebooksDataset
from geomfum.shape import TriangleMesh
from geomfum.plot import *

# %%
#load data
dataset = NotebooksDataset()
mesh = TriangleMesh.from_file(dataset.get_filename("cat-00"))

mesh.n_vertices, mesh.n_faces
# Out:
# (7207, 14410)

# %%
plotter = MeshPlotter.from_registry(which='plotly')
plotter.plot(mesh)

# %%
plotter = MeshPlotter.from_registry(which='pyvista')
plotter.plot(mesh)
# Out:
# c:\Users\giuli\OneDrive\Research\geomfum_proj\venv\Lib\site-packages\pyvista\jupyter\notebook.py:37: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (c:\Users\giuli\OneDrive\Research\geomfum_proj\venv\Lib\site-packages\trame\widgets\__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
